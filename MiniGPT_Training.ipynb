# %% [markdown]
# # MiniGPT: Technical Question Assistant
# This notebook handles the setup, training, and testing of our specialized MiniGPT model on Google Colab.

# %% [markdown]
# ## 1. Setup Environment

# %%
# Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Start Training
# The training script includes auto-resume logic. If a checkpoint exists in `./checkpoints/latest.pt`, it will continue from there.

# %%
# !python train.py

# %% [markdown]
# ## 3. Inference / Testing
# Run the following cell to interact with the model.

# %%
# !python generate.py
