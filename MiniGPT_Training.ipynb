# %% [markdown]
# # MiniGPT: Technical Question Assistant (Persistent Training)
# This notebook handles the setup, training, and testing of our specialized MiniGPT model on Google Colab with **Google Drive persistence**.

# %% [markdown]
# ## 1. Mount Google Drive
# Run this cell to connect your Google Drive. This ensures your checkpoints (`.pt` files) are saved permanently even if the Colab session ends.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define your project path on Drive
import os
PROJECT_PATH = '/content/drive/MyDrive/MiniGPT-Jay'

if not os.path.exists(PROJECT_PATH):
    # Clone if it doesn't exist, or just create the folder
    # !git clone https://github.com/JayThakare25/MiniGPT-Jay.git "{PROJECT_PATH}"

# %cd "{PROJECT_PATH}"
# !ls

# %% [markdown]
# ## 2. Setup Environment

# %%
# Install dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Start Training
# The training script saves to `./checkpoints/`, which is now on your Google Drive.

# %%
# !python train.py

# %% [markdown]
# ## 4. Inference / Testing
# Run the following cell to interact with the model.

# %%
# !python generate.py
